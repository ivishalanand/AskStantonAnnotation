# %%
import httpx

# %%
LANGFUSE_PUBLIC_KEY = "pk-lf-f6ea7cfd-fb41-4ee5-813e-8152763a5762"
LANGFUSE_SECRET_KEY = "sk-lf-ff29c0d1-50fd-413b-bfb1-136e4782e9d3"

# %% [markdown]
# ## Get Specific Item by ID

# %%
# Function to get a specific item from an annotation queue
async def get_queue_item(queue_id, item_id):
    """
    Get a specific item from an annotation queue.
    
    Args:
        queue_id (str): The unique identifier of the annotation queue
        item_id (str): The unique identifier of the annotation queue item
        
    Returns:
        dict: Item details including:
            - id: Item ID
            - queueId: Queue ID
            - objectId: ID of the object being annotated
            - objectType: Type of object (e.g., "TRACE")
            - status: Status (e.g., "PENDING", "COMPLETED")
            - completedAt: Completion timestamp (if completed)
            - createdAt: Creation timestamp
            - updatedAt: Last update timestamp
    """
    import base64
    
    auth_string = f"{LANGFUSE_PUBLIC_KEY}:{LANGFUSE_SECRET_KEY}"
    auth_bytes = auth_string.encode('ascii')
    auth_b64 = base64.b64encode(auth_bytes).decode('ascii')
    
    async with httpx.AsyncClient() as client:
        response = await client.get(
            f"https://us.cloud.langfuse.com/api/public/annotation-queues/{queue_id}/items/{item_id}",
            headers={
                "Authorization": f"Basic {auth_b64}"
            }
        )
        return response.json()

# Example: Get a specific item from the queue
queue_id = "cmccb2ym402tpad07asml1mb7"  # test - vishal queue
item_id = "cmel01iqn08szad08a89nek6f"

item_details = await get_queue_item(queue_id, item_id)

print("Specific Item Details:")
print(f"  Item ID: {item_details['id']}")
print(f"  Queue ID: {item_details['queueId']}")
print(f"  Object ID: {item_details['objectId']}")
print(f"  Object Type: {item_details['objectType']}")
print(f"  Status: {item_details['status']}")
print(f"  Created: {item_details['createdAt']}")
print(f"  Updated: {item_details['updatedAt']}")
if item_details.get('completedAt'):
    print(f"  Completed: {item_details['completedAt']}")
# Out:
# Specific Item Details:
#   Item ID: cmel01iqn08szad08a89nek6f
#   Queue ID: cmccb2ym402tpad07asml1mb7
#   Object ID: 3fbb955f-94d3-43ec-80a9-d893e761c6ab
#   Object Type: SESSION
#   Status: PENDING
#   Created: 2025-08-21T06:07:03.454Z
#   Updated: 2025-08-21T06:07:03.454Z

# %%
async def get_session_by_id(session_id):
    """
    Get a session by its ID from Langfuse API.
    
    Args:
        session_id (str): The unique identifier of the session
        
    Returns:
        dict: Session details including traces and metadata
    """
    import base64
    
    auth_string = f"{LANGFUSE_PUBLIC_KEY}:{LANGFUSE_SECRET_KEY}"
    auth_bytes = auth_string.encode('ascii')
    auth_b64 = base64.b64encode(auth_bytes).decode('ascii')
    
    async with httpx.AsyncClient() as client:
        response = await client.get(
            f"https://us.cloud.langfuse.com/api/public/sessions/{session_id}",
            headers={
                "Authorization": f"Basic {auth_b64}"
            }
        )
        if response.status_code == 200:
            return response.json()
        else:
            return {"error": f"Failed to fetch session: {response.status_code}", "details": response.text}

# Example: Fetch session data
session_id = "090cc1ff-a8c0-482d-af7a-64109ae09d57"  # From the queue item above
session_data = await get_session_by_id(session_id)

print("Session Data:")
if "error" in session_data:
    print(f"Error: {session_data['error']}")
    print(f"Details: {session_data['details']}")
else:
    print(f"  Session ID: {session_data['id']}")
    print(f"  Created At: {session_data['createdAt']}")
    print(f"  Project ID: {session_data['projectId']}")
    print(f"  Environment: {session_data.get('environment', 'None')}")
    print(f"  Number of traces: {len(session_data.get('traces', []))}")
    
    if session_data.get('traces'):
        print("\n  Traces:")
        for i, trace in enumerate(session_data['traces']):  # Show first 3 traces
            print(f"    Trace {i+1}:")
            print(f"      ID: {trace['id']}")
            print(f"      Timestamp: {trace['timestamp']}")
            print(f"      Name: {trace.get('name', 'None')}")
            print(f"      Input: {trace.get('input', 'None')}")
            print(f"      Output: {trace.get('output', 'None')}")
        
        if len(session_data['traces']) > 3:
            print(f"    ... and {len(session_data['traces']) - 3} more traces")
# Out:
# Session Data:
#   Session ID: 090cc1ff-a8c0-482d-af7a-64109ae09d57
#   Created At: 2025-08-28T21:13:55.124Z
#   Project ID: cmaxr5f6h002bad07s9drmhxz
#   Environment: default
#   Number of traces: 8
#
#   Traces:
#     Trace 1:
#       ID: 16b0a4cc-2082-4479-8fd0-8f4caa0d1ea3
#       Timestamp: 2025-09-04T01:53:59.075Z
#       Name: LangGraph
#       Input: {'messages': [{'content': 'Can you rephrase it so it looks like it was written by a lawyer?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'c88cc65a-dbfe-4c6d-a5dd-f694b9780f5e', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}, {'content': [{'text': 'Two feet is definitely a significant overhang. \n\nAre the branches causing any specific problems for you - like blocking sunlight, dropping leaves or debris, or interfering with anything on your property?', 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '2899de6e-8cbc-4854-aa47-f3abe9a4a229'}, 'type': 'ai', 'name': None, 'id': 'run--e7919bee-a43c-459c-be5f-0fd4f3bef959', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2271, 'output_tokens': 44, 'total_tokens': 2315, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "It's dropping leaves into my yard", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '016fa53b-5c20-4ff4-a4ec-88ece6fb4d90', 'example': False}, {'content': [{'text': "That's understandable - having to constantly clean up someone else's tree debris on your own property would be annoying.\n\nHave you spoken with your neighbor about this issue yet? If so, what did they say when you asked them to trim the branches?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'f1f490c1-cd6e-44b3-9a91-3d9c8a2b5307'}, 'type': 'ai', 'name': None, 'id': 'run--0beef298-d6f1-4bd8-82ca-c2214207b8a6', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2325, 'output_tokens': 56, 'total_tokens': 2381, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Can you direct me to resourc ...
#     Trace 2:
#       ID: f88fdae5-f251-4209-8a50-65b5a017b2a7
#       Timestamp: 2025-08-28T21:17:15.640Z
#       Name: LangGraph
#       Input: {'messages': [{'content': 'I want to write a letter to ask them to do it. What should I put in my letter?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '6c2701b8-d6d6-401f-86ab-ec5ce73dd9da', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}, {'content': [{'text': 'Two feet is definitely a significant overhang. \n\nAre the branches causing any specific problems for you - like blocking sunlight, dropping leaves or debris, or interfering with anything on your property?', 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '2899de6e-8cbc-4854-aa47-f3abe9a4a229'}, 'type': 'ai', 'name': None, 'id': 'run--e7919bee-a43c-459c-be5f-0fd4f3bef959', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2271, 'output_tokens': 44, 'total_tokens': 2315, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "It's dropping leaves into my yard", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '016fa53b-5c20-4ff4-a4ec-88ece6fb4d90', 'example': False}, {'content': [{'text': "That's understandable - having to constantly clean up someone else's tree debris on your own property would be annoying.\n\nHave you spoken with your neighbor about this issue yet? If so, what did they say when you asked them to trim the branches?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'f1f490c1-cd6e-44b3-9a91-3d9c8a2b5307'}, 'type': 'ai', 'name': None, 'id': 'run--0beef298-d6f1-4bd8-82ca-c2214207b8a6', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2325, 'output_tokens': 56, 'total_tokens': 2381, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Can you direct me to resourc ...
#     Trace 3:
#       ID: a843963a-40cc-47f8-ac7c-292f85a2ac29
#       Timestamp: 2025-08-28T21:16:08.367Z
#       Name: LangGraph
#       Input: {'messages': [{'content': "I'm in salt lake city, utah", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '07cf5779-6f99-4aaa-bd52-2f9779eb50e0', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}, {'content': [{'text': 'Two feet is definitely a significant overhang. \n\nAre the branches causing any specific problems for you - like blocking sunlight, dropping leaves or debris, or interfering with anything on your property?', 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '2899de6e-8cbc-4854-aa47-f3abe9a4a229'}, 'type': 'ai', 'name': None, 'id': 'run--e7919bee-a43c-459c-be5f-0fd4f3bef959', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2271, 'output_tokens': 44, 'total_tokens': 2315, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "It's dropping leaves into my yard", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '016fa53b-5c20-4ff4-a4ec-88ece6fb4d90', 'example': False}, {'content': [{'text': "That's understandable - having to constantly clean up someone else's tree debris on your own property would be annoying.\n\nHave you spoken with your neighbor about this issue yet? If so, what did they say when you asked them to trim the branches?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'f1f490c1-cd6e-44b3-9a91-3d9c8a2b5307'}, 'type': 'ai', 'name': None, 'id': 'run--0beef298-d6f1-4bd8-82ca-c2214207b8a6', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2325, 'output_tokens': 56, 'total_tokens': 2381, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Can you direct me to resourc ...
#     Trace 4:
#       ID: 418cd886-d9f4-45f6-beab-1a866f15e872
#       Timestamp: 2025-08-28T21:15:47.801Z
#       Name: LangGraph
#       Input: {'messages': [{'content': 'Can you direct me to resources that tell me about my rights?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '5a845684-20b4-496c-a8f8-5f2b29110d10', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}, {'content': [{'text': 'Two feet is definitely a significant overhang. \n\nAre the branches causing any specific problems for you - like blocking sunlight, dropping leaves or debris, or interfering with anything on your property?', 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '2899de6e-8cbc-4854-aa47-f3abe9a4a229'}, 'type': 'ai', 'name': None, 'id': 'run--e7919bee-a43c-459c-be5f-0fd4f3bef959', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2271, 'output_tokens': 44, 'total_tokens': 2315, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "It's dropping leaves into my yard", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '016fa53b-5c20-4ff4-a4ec-88ece6fb4d90', 'example': False}, {'content': [{'text': "That's understandable - having to constantly clean up someone else's tree debris on your own property would be annoying.\n\nHave you spoken with your neighbor about this issue yet? If so, what did they say when you asked them to trim the branches?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'f1f490c1-cd6e-44b3-9a91-3d9c8a2b5307'}, 'type': 'ai', 'name': None, 'id': 'run--0beef298-d6f1-4bd8-82ca-c2214207b8a6', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2325, 'output_tokens': 56, 'total_tokens': 2381, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Can you direct me to resourc ...
#     Trace 5:
#       ID: f1f490c1-cd6e-44b3-9a91-3d9c8a2b5307
#       Timestamp: 2025-08-28T21:15:09.687Z
#       Name: LangGraph
#       Input: {'messages': [{'content': "It's dropping leaves into my yard", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '016fa53b-5c20-4ff4-a4ec-88ece6fb4d90', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}, {'content': [{'text': 'Two feet is definitely a significant overhang. \n\nAre the branches causing any specific problems for you - like blocking sunlight, dropping leaves or debris, or interfering with anything on your property?', 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '2899de6e-8cbc-4854-aa47-f3abe9a4a229'}, 'type': 'ai', 'name': None, 'id': 'run--e7919bee-a43c-459c-be5f-0fd4f3bef959', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2271, 'output_tokens': 44, 'total_tokens': 2315, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "It's dropping leaves into my yard", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '016fa53b-5c20-4ff4-a4ec-88ece6fb4d90', 'example': False}, {'content': [{'text': "That's understandable - having to constantly clean up someone else's tree debris on your own property would be annoying.\n\nHave you spoken with your neighbor about this issue yet? If so, what did they say when you asked them to trim the branches?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'f1f490c1-cd6e-44b3-9a91-3d9c8a2b5307'}, 'type': 'ai', 'name': None, 'id': 'run--0beef298-d6f1-4bd8-82ca-c2214207b8a6', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2325, 'output_tokens': 56, 'total_tokens': 2381, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}]}
#     Trace 6:
#       ID: 2899de6e-8cbc-4854-aa47-f3abe9a4a229
#       Timestamp: 2025-08-28T21:14:34.572Z
#       Name: LangGraph
#       Input: {'messages': [{'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': 'Some branches are two feet over', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '999569ba-f83a-4629-a459-75e456056017', 'example': False}, {'content': [{'text': 'Two feet is definitely a significant overhang. \n\nAre the branches causing any specific problems for you - like blocking sunlight, dropping leaves or debris, or interfering with anything on your property?', 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '2899de6e-8cbc-4854-aa47-f3abe9a4a229'}, 'type': 'ai', 'name': None, 'id': 'run--e7919bee-a43c-459c-be5f-0fd4f3bef959', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2271, 'output_tokens': 44, 'total_tokens': 2315, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}]}
#     Trace 7:
#       ID: efe4e4fc-5a18-4d8b-b6fa-6b66f212a252
#       Timestamp: 2025-08-28T21:14:13.706Z
#       Name: LangGraph
#       Input: {'messages': [{'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}, {'content': "Their tree is growing over my property line and they won't cut it", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3ba7f30e-147d-43e7-95e9-599d200d6f79', 'example': False}, {'content': [{'text': "That's frustrating when a neighbor won't address something affecting your property. Tree disputes can definitely create tension.\n\nHow far is the tree extending over your property line? Is it just branches, or are there other parts like roots causing issues too?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': 'efe4e4fc-5a18-4d8b-b6fa-6b66f212a252'}, 'type': 'ai', 'name': None, 'id': 'run--6e79c38a-c64d-4560-bb9a-68d7950a9175', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2209, 'output_tokens': 53, 'total_tokens': 2262, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}]}
#     Trace 8:
#       ID: 14999254-f3a0-4904-878b-2e7825c79bf7
#       Timestamp: 2025-08-28T21:13:46.707Z
#       Name: LangGraph
#       Input: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}]}
#       Output: {'messages': [{'content': 'my neighbor is bothering me', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '717d4a2d-a027-4dae-a56c-259f11303b3e', 'example': False}, {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?", 'type': 'text', 'index': 0}], 'additional_kwargs': {}, 'response_metadata': {'model_name': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'}, 'type': 'ai', 'name': None, 'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 2145, 'output_tokens': 47, 'total_tokens': 2192, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}]}
#     ... and 5 more traces

# %%
# Sample Trace data
trace
# Out:
# {'id': '14999254-f3a0-4904-878b-2e7825c79bf7',
#  'projectId': 'cmaxr5f6h002bad07s9drmhxz',
#  'name': 'LangGraph',
#  'timestamp': '2025-08-28T21:13:46.707Z',
#  'environment': 'default',
#  'tags': [],
#  'bookmarked': False,
#  'release': None,
#  'version': None,
#  'userId': '1e62abdf-37e9-4808-897c-ff6fb7fe5413',
#  'sessionId': '090cc1ff-a8c0-482d-af7a-64109ae09d57',
#  'public': False,
#  'input': {'messages': [{'content': 'my neighbor is bothering me',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '717d4a2d-a027-4dae-a56c-259f11303b3e',
#     'example': False}]},
#  'output': {'messages': [{'content': 'my neighbor is bothering me',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '717d4a2d-a027-4dae-a56c-259f11303b3e',
#     'example': False},
#    {'content': [{'text': "I'm sorry to hear your neighbor is bothering you. That can be really stressful when it's happening where you live.\n\nCan you tell me what specifically your neighbor is doing that's bothering you?",
#       'type': 'text',
#       'index': 0}],
#     'additional_kwargs': {},
#     'response_metadata': {'model_name': 'claude-sonnet-4-20250514',
#      'stop_reason': 'end_turn',
#      'stop_sequence': None,
#      'langfuse_trace_id_run_id': '14999254-f3a0-4904-878b-2e7825c79bf7'},
#     'type': 'ai',
#     'name': None,
#     'id': 'run--d4b5a712-deb4-42d7-95d8-bc6182e05e35',
#     'example': False,
#     'tool_calls': [],
#     'invalid_tool_calls': [],
#     'usage_metadata': {'input_tokens': 2145,
#      'output_tokens': 47,
#      'total_tokens': 2192,
#      'input_token_details': {'cache_creation': 0, 'cache_read': 0}}}]},
#  'metadata': {'thread_id': '090cc1ff-a8c0-482d-af7a-64109ae09d57',
#   'model': 'claude-3-7-sonnet-latest',
#   'user_id': '1e62abdf-37e9-4808-897c-ff6fb7fe5413',
#   'spicy_level': 0.8},
#  'createdAt': '2025-08-28T21:13:48.000Z',
#  'updatedAt': '2025-08-28T21:13:58.688Z',
#  'externalId': None}
